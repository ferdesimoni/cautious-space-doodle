# %%
# Esta es una modificacion del script original para google colab, para que funcione en github codespaces
# Hecho por @LUCAST o @Lucast1574 o @Lucast_1574 en github y otras redes sociales
# Solo versiones +1.17
# Versiones disponibles testeadas:
# - 1.20.4
# - 1.20.3
# - 1.20.2
# - 1.20.1
# - 1.20
# - 1.19.4
# - 1.19.3
# - 1.19.2
# - 1.19.1
# - 1.19
# - 1.18.2
# - 1.18.1
# - 1.18
# - 1.17.1




version = '1.19.2' # Version de Minecraft a usar

#Chose server type. Currently available versions:
# - paper (Lo más vanilla. Es lo mismo que SPIGOT, bukkit, etc)
# - forge (Para usar MODS. Es básicamente FORGE) [Aviso, la instalación tarda APROX 10-15 min, al ejecutar el primer paso, esperar a que ponga COMPLETADO]
# - fabric (Para jugar Fabric. Es una alternativa a Forge)
# - vanilla (Minecraft Vanilla sin mods ni plugins)
# - snapshot (En "version" tendrás que poner el nombre de la SNAPSHOT, EJ: 23w42a)
# - mohist (Versión de Minecraft que combina Forge y Bukkit) 1.20.1 29/09/24 ultima version disponible
# - catserver (Versión de Minecraft que combina Forge y Bukkit) 1.18.2 29/09/24 ultima version disponible
# - purpur (Versión de Minecraft que combina paper y Bukkit)

server_type = 'forge'

#Importa librerias necesarias para el funcionamiento del script 

import os
import requests
import json


server_directory = "Minecraft-server"

# Crea el directorio del servidor en codespace

os.makedirs(server_directory, exist_ok=True)
os.chdir(server_directory)

# Inicio interno... Descarga el servidor 

if server_type == 'paper':
    a = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version)

    b = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]))

    print("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"])
    serverURL = "https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"]

if server_type == 'forge':
    serverURL = "https://serverjars.com/api/fetchJar/modded/forge/" + version

if server_type == 'vanilla':
    serverURL = "https://serverjars.com/api/fetchJar/vanilla/vanilla/" + version

if server_type == 'snapshot':
    serverURL = "https://serverjars.com/api/fetchJar/vanilla/snapshot/" + version

if server_type == 'fabric':
    serverURL = 'https://serverjars.com/api/fetchJar/modded/fabric/'

if server_type == 'mohist':
    serverURL = "https://serverjars.com/api/fetchJar/modded/mohist/" + version
    
if server_type == 'catserver':
    serverURL = "https://serverjars.com/api/fetchJar/modded/catserver/" + version

if server_type == 'purpur':
    serverURL = "https://serverjars.com/api/fetchJar/servers/purpur/" + version



jar_name = {'paper': 'paper.jar', 'fabric': 'fabric-server-launch.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': "snapshot.jar", 'mohist': "mohist.jar", 
            'catserver': "catserver.jar", 'purpur': "purpur.jar"}

print('Descargando el tipo de servidor: ')

if serverURL:
    print('Descargando a GitHub Codespaces...')
    r = requests.get(serverURL)

    if r.status_code == 200:
        with open(jar_name[server_type], 'wb') as f:
            f.write(r.content)
    else:
        print('Error '+ str(r.status_code) + '! La versión que has elegido probablemente no funciona.')


# Correr en un camino especifico

if server_type == 'fabric':
    # !java -jar fabric-server-launch.jar server -mcversion $version -downloadMinecraft

elif server_type == 'forge':
    # %cd "/workspaces/codespaces-jupyter/Minecraft-server"
    # !java -jar forge.jar --installServer

elif server_type == 'vanilla':
    # %cd "/workspaces/codespaces-jupyter/Minecraft-server"
    # !java -jar vanilla.jar --installServer

# Guarda el archivo de configuración localmente
colabconfig = {"server_type": server_type, "server_version": version}
with open("colabconfig.json", 'w') as config_file:
    json.dump(colabconfig, config_file)

# Imprime un mensaje de finalización
print('Completado!')
# Cambie el eula a true para aceptar los términos de Minecraft
# !echo "eula=true" >> eula.txt

# %%
#Tienes que poner el spawn proteccion en 0 para que puedas jugar de manera normal(esto dentro de Server.properties)
#importa librerias necesarias para ejecucion

import requests

import time

import os

import re

import json

import glob

import threading

import subprocess


#Actualizacion de lista de paquetes

# !sudo apt update &>/dev/null && echo "el apt cache fue actualizado correctamente" || echo "la actualizacion del apt cache fallo, es posible que recibas paquetes obsoletos"

#Asignar archivos al directorio


os.makedirs("/workspaces/codespaces-jupyter/Minecraft-server", exist_ok=True)

os.chdir("/workspaces/codespaces-jupyter/Minecraft-server")

# !ls #lista los archivos del directorio para verificarlos



#Importacion del archivo de configuracion


config_path = "/workspaces/codespaces-jupyter/Minecraft-server/colabconfig.json"

if os.path.isfile(config_path):

    with open(config_path) as config_file:

        colabconfig = json.load(config_file)

else:

    colabconfig = {"server_type": "generic"} # Usar la configura default si no existe

    with open(config_path, 'w') as new_config_file:

        json.dump(colabconfig, new_config_file)

# Instalar OpenJDK

version = colabconfig["server_version"]

# Ejecuta un comando en la terminal

def ejecutar_comando(comando):
    proceso = subprocess.run(comando, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Comprueba si el comando se ejecutó con éxito
    if proceso.returncode == 0:
        print("OpenJDK 17 instalado correctamente")
    else:
        print("Fallo al instalar OpenJDK 17")

# Purga versiones anteriores de OpenJDK
ejecutar_comando('sudo apt-get purge openjdk* -y')

# Instala OpenJDK 17
ejecutar_comando('sudo apt-get install openjdk-17-jre-headless -y')

# Chequeo de version de java

java_ver = !java -version 2>&1 | awk -F[\"\.] -v OFS=. 'NR==1{print $2}'

#Lista de posibles archivos .jar

jar_list = {'paper': 'paper.jar', 'fabric': 'fabric-server-launch.jar', 'generic': 'server.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': 'snapshot.jar', 'mohist': "mohist.jar", 'catserver': "catserver.jar", 'purpur': "purpur.jar"}

jar_name = jar_list[colabconfig["server_type"]]

# Argumentos de java.

if colabconfig["server_type"] == "paper":

    server_flags = "-XX:+UseG1GC -XX:+ParallelRefProcEnabled -XX:MaxGCPauseMillis=200 -XX:+UnlockExperimentalVMOptions -XX:+DisableExplicitGC -XX:+AlwaysPreTouch -XX:G1NewSizePercent=30 -XX:G1MaxNewSizePercent=40 -XX:G1HeapRegionSize=8M -XX:G1ReservePercent=20 -XX:G1HeapWastePercent=5 -XX:G1MixedGCCountTarget=4 -XX:InitiatingHeapOccupancyPercent=15 -XX:G1MixedGCLiveThresholdPercent=90 -XX:G1RSetUpdatingPauseTimePercent=5 -XX:SurvivorRatio=32 -XX:+PerfDisableSharedMem -XX:MaxTenuringThreshold=1 -Dusing.aikars.flags=https://mcflags.emc.gs -Daikars.new.flags=true"

else:

    server_flags = "" # No se necesitan banderas para servidores que no sean de paper

#Argumentos JVM

memory_allocation = "-Xms10G -Xmx10G"



# Elige el servicio de tunelacion que desees

# Opciones disponibles: ngrok

tunnel_service = "ngrok"

print("Usando", tunnel_service)


#Condicional de tunelacion del servidor



if tunnel_service == "ngrok":

    # !pip -q install pyngrok  #Aqui se instala el ngrok en el servidor

    from pyngrok import conf, ngrok



    # Obten tu token de ngrok

    print("Consigue tu authtoken de https://dashboard.ngrok.com/auth") #Consigue aqui tu token de ngrok, sera dinamico, si quieres que sea estatico, necesitaras la version premiun de ngrok

    import getpass



    # v - - - - - - - TOKEN - - - - - - - v



    authtoken = "2dIBXD9NsAJplfeXWdoNi5NSw8t_2xRaaHbj3fgbBAoTbBdbq" # <---- TOKEN NGROK (PON AQUÍ TU TOKEN [TIENE QUE ESTAR ENTRE LAS "COMILLAS"])

    ! ngrok authtoken $authtoken # logeo en ngrok



    #Establecimiento de region de ngrok



    #v - - - - - - - REGIONES DISPONIBLES - - - - - - - v

    # ap - Asia/Pacifico (Singapore)

    # au - Australia (Sydney)

    # eu - Europa (Frankfurt - Alemania)

    # in - India (Mumbai)

    # jp - Japon (Tokyo)

    # sa - America del sur (São Paulo - Brasil)

    # us - Estados unidos (Ohio)

    conf.get_default().region = 'sa' # <--- Cambia esto por la region que quieras



    # Conectar a ngrok

    url = ngrok.connect(25565, 'tcp')

    print('La IP de tu servidor es ' + ((str(url).split('"')[1::2])[0]).replace('tcp://', ''))

    #Si obtienes el servicio premiun de ngrok borra las dos lineas de codigo de arriba y quitale el # a estas a continuacion:

    #subdominio = "mi-subdominio"

    #url = ngrok.connect(25565, 'tcp', subdomain=subdominio)

    #print('La IP de tu servidor es ' + url.replace('tcp://', ''))

elif tunnel_service == "playit":

    ! curl -SsL https://playit-cloud.github.io/ppa/key.gpg | sudo apt-key add -
    ! sudo curl -SsL -o /etc/apt/sources.list.d/playit-cloud.list https://playit-cloud.github.io/ppa/playit-cloud.list
    ! sudo apt update &>/dev/null && sudo apt install playit &>/dev/null && echo "Playit.gg installed" || echo "Failed to install playit"
    print('Starting server...')
    ! playit & java $memory_allocation $server_flags -jar $jar_name nogui

print('Iniciando servidor...')

def get_users():
    url = 'https://jsonplaceholder.typicode.com/users'
    try:
        response = requests.get(url)
        if response.status_code == 200:
            data = response.json()
            print("Lista de usuarios:")
            for user in data:
                print(f"Nombre: {user['name']}, Email: {user['email']}")
        else:
            print(f"Error al hacer la solicitud. Código de estado: {response.status_code}")
    except requests.RequestException as e:
        print(f"Error de conexión: {e}")

# Función para ejecutar get_users() cada 25 minutos
def repeat_get_users():
    while True:
        get_users()
        time.sleep(600)  # Espera 10 minutos

# Inicia un hilo para ejecutar repeat_get_users() en segundo plano
user_thread = threading.Thread(target=repeat_get_users)
user_thread.start()

if colabconfig["server_type"] == "forge":

    version = colabconfig["server_version"]
    
    forgefiles = f"/workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/forge/"
    
    forgepreversion = os.listdir(forgefiles)
    
    if forgepreversion:
    
        forgeversion = forgepreversion[0]
        forgeversionchecked = forgeversion.replace(".jar", "")
        print("La versión de Forge es:", forgeversionchecked)
    
    else:
    
        print("No se encontraron archivos en el directorio Forge.")
    
    pathtoforge = glob.glob(f"/workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/forge/{forgeversionchecked}/unix_args.txt")

    if pathtoforge: # Checa si la lista no esta vacia

        path = pathtoforge[0] # Obtiene la primera ruta de la lista

        print(path)

        # !java @user_jvm_args.txt "@{path}" "$@"

    else:

        print("No se encontro el archivo unix_args.txt.")

#Si el servidor es de tipo Vanilla o paper o mohist o catserver o purpur

else:
    #Ejecuta el archivo jar del servidor
    
    # !java $memory_allocation $server_flags -jar $jar_name nogui   

# Ciclo para realizar las solicitudes a JSONPlaceholder cada minuto

while True:
    time.sleep(60)  # Espera 1 minuto
# Out:
# el apt cache fue actualizado correctamente
# READ_ME.txt		   localconfigs       start.ps1
# banned-ips.json		   logs		      start.sh
# banned-players.json	   modernfix	      user_jvm_args.txt
# colabconfig.json	   mods		      usercache.json
# config			   ops.json	      usernamecache.json
# configureddefaults	   patchouli_books    variables.txt
# crash-reports		   run.bat	      whitelist.json
# defaultconfigs		   run.sh	      world
# enigmatic_persistence.dat  schematics	      xaerominimap-common.txt
# eula.txt		   server-icon.png    xaeroworldmap-common.txt
# libraries		   server.properties
# OpenJDK 17 instalado correctamente
# OpenJDK 17 instalado correctamente
# Usando ngrok
# Consigue tu authtoken de https://dashboard.ngrok.com/auth
# Authtoken saved to configuration file: /home/codespace/.config/ngrok/ngrok.yml
# La IP de tu servidor es 0.tcp.sa.ngrok.io:13559
# Iniciando servidor...
# La versión de Forge es: 1.19.2-43.3.8
# /workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/forge/1.19.2-43.3.8/unix_args.txt
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [18:41:38] [main/INFO] [cp.mo.mo.Launcher/MODLAUNCHER]: ModLauncher running: args [--launchTarget, forgeserver, --fml.forgeVersion, 43.3.8, --fml.mcVersion, 1.19.2, --fml.forgeGroup, net.minecraftforge, --fml.mcpVersion, 20220805.130853]
# [18:41:38] [main/INFO] [cp.mo.mo.Launcher/MODLAUNCHER]: ModLauncher 10.0.8+10.0.8+main.0ef7e830 starting: java version 21.0.2 by Microsoft; OS Linux arch amd64 version 6.2.0-1019-azure
# [18:41:40] [main/INFO] [mixin/]: SpongePowered MIXIN Subsystem Version=0.8.5 Source=union:/workspaces/codespaces-jupyter/Minecraft-server/libraries/org/spongepowered/mixin/0.8.5/mixin-0.8.5.jar%2363!/ Service=ModLauncher Env=SERVER
# [18:41:41] [main/WARN] [ne.mi.fm.lo.mo.ModFileParser/LOADING]: Mod file /workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/fmlcore/1.19.2-43.3.8/fmlcore-1.19.2-43.3.8.jar is missing mods.toml file
# [18:41:41] [main/WARN] [ne.mi.fm.lo.mo.ModFileParser/LOADING]: Mod file /workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/javafmllanguage/1.19.2-43.3.8/javafmllanguage-1.19.2-43.3.8.jar is missing mods.toml file
# [18:41:41] [main/WARN] [ne.mi.fm.lo.mo.ModFileParser/LOADING]: Mod file /workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/lowcodelanguage/1.19.2-43.3.8/lowcodelanguage-1.19.2-43.3.8.jar is missing mods.toml file
# [18:41:41] [main/WARN] [ne.mi.fm.lo.mo.ModFileParser/LOADING]: Mod file /workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/mclanguage/1.19.2-43.3.8/mclanguage-1.19.2-43.3.8.jar is missing mods.toml file
# [18:41:41] [main/WARN] [ne.mi.ja.se.JarSelector/]: Attempted to select two dependency jars from JarJar which have the same identification: Mod File:  and Mod File: . Using Mod File:
# [18:41:41] [main/WARN] [ne.mi.ja.se.JarSelector/]: Attempted to select a dependency jar for JarJar which was passed in as source: terrablender. Using Mod File: /workspaces/codespaces-jupyter/Minecraft-server/mods/TerraBlender-forge-1.19.2-2.0.1.166.jar
# [18:41:41] [main/WARN] [ne.mi.ja.se.JarSelector/]: Attempted to select a dependency jar for JarJar which was passed in as source: resourcefullib. Using Mod File: /workspaces/codespaces-jupyter/Minecraft-server/mods/resourcefullib-forge-1.19.2-1.1.24.jar
# [18:41:41] [main/WARN] [ne.mi.ja.se.JarSelector/]: Attempted to select a dependency jar for JarJar which was passed in as source: botarium. Using Mod File: /workspaces/codespaces-jupyter/Minecraft-server/mods/botarium-forge-1.19.2-1.9.0.jar
# [18:41:41] [main/WARN] [ne.mi.ja.se.JarSelector/]: Attempted to select a dependency jar for JarJar which was passed in as source: curios. Using Mod File: /workspaces/codespaces-jupyter/Minecraft-server/mods/curios-forge-1.19.2-5.1.4.4.jar
# [18:41:41] [main/INFO] [ne.mi.fm.lo.mo.JarInJarDependencyLocator/]: Found 16 dependencies adding them to mods collection
# [18:41:48] [main/INFO] [mixin/]: Compatibility level set to JAVA_17
# [18:41:48] [main/ERROR] [mixin/]: Mixin config spruceui.mixins.json does not specify "minVersion" property
# [18:41:49] [main/INFO] [mixin/]: Successfully loaded Mixin Connector [com.sonicether.soundphysics.MixinConnector]
# [18:41:49] [main/INFO] [mixin/]: Successfully loaded Mixin Connector [ca.spottedleaf.starlight.mixin.MixinConnector]
# [18:41:49] [main/INFO] [mixin/]: Successfully loaded Mixin Connector [com.aizistral.enigmaticlegacy.MixinConnector]
# [18:41:49] [main/INFO] [cp.mo.mo.LaunchServiceHandler/MODLAUNCHER]: Launching target 'forgeserver' with arguments []
# [18:41:49] [main/INFO] [ModernFix/]: Loaded configuration file for ModernFix 5.12.0+mc1.19.2: 79 options available, 1 override(s) found
# [18:41:49] [main/WARN] [ModernFix/]: Option 'mixin.perf.resourcepacks' overriden (by user configuration) to 'false'
# [18:41:49] [main/INFO] [ModernFix/]: Applying Nashorn fix
# [18:41:49] [main/INFO] [ModernFix/]: Applied Forge config corruption patch
# [18:41:49] [main/WARN] [mixin/]: Reference map 'lmft-forge-refmap.json' for lmft.mixins.json could not be read. If this is a development environment you can ignore this message
# [18:41:49] [main/WARN] [mixin/]: Reference map 'nitrogen_internals.refmap.json' for nitrogen_internals.mixins.json could not be read. If this is a development environment you can ignore this message
# [18:41:49] [main/WARN] [mixin/]: Reference map 'EpheroLib-refmap.json' for epherolib.mixins.json could not be read. If this is a development environment you can ignore this message
# [18:41:49] [main/WARN] [mixin/]: Reference map 'tfmg.refmap.json' for design_decor.mixins.json could not be read. If this is a development environment you can ignore this message
# [18:41:49] [main/WARN] [mixin/]: Reference map 'thirst.refmap.json' for villagercomfort.mixin.json could not be read. If this is a development environment you can ignore this message
# [18:41:49] [main/WARN] [mixin/]: Reference map 'idas.refmap.json' for idas.mixins.json could not be read. If this is a development environment you can ignore this message
# [18:41:49] [main/WARN] [mixin/]: Reference map 'fastpaintings-forge-refmap.json' for fastpaintings-forge.mixins.json could not be read. If this is a development environment you can ignore this message
# [18:41:49] [main/WARN] [mixin/]: Reference map 'mixins.wares.refmap.json' for mixins.wares.json could not be read. If this is a development environment you can ignore this message
# [18:41:49] [Thread-0/INFO] [ModernFix/]: Please use /mfsrc to reload any changed mod config files
# [18:41:49] [main/WARN] [mixin/]: Reference map 'createair.mixins.refmap.json' for createair.mixins.json could not be read. If this is a development environment you can ignore this message
# [18:41:49] [main/WARN] [mixin/]: Reference map 'create_crystal_clear.refmap.json' for create_crystal_clear.mixins.json could not be read. If this is a development environment you can ignore this message
# [18:41:49] [main/WARN] [mixin/]: Reference map 'QualitysDelight.refmap.json' for qualitysdelight.mixins.json could not be read. If this is a development environment you can ignore this message
# [ImprovableSkills]: Patching ItemStack.hurtAndBreak
# [18:41:50] [main/INFO] [ne.mi.co.Co.placebo/COREMODLOG]: Patching IForgeItemStack#getEnchantmentLevel
# [18:41:50] [main/INFO] [ne.mi.co.Co.placebo/COREMODLOG]: Patching IForgeItemStack#getEnchantmentLevel
# [Serene Seasons Transformer]: Transforming m_8714_ (Lnet/minecraft/world/level/chunk/LevelChunk;I)V in net/minecraft/server/level/ServerLevel
# [Serene Seasons Transformer]: Successfully patched tickChunk
# [18:41:50] [main/WARN] [mixin/]: Error loading class: dev/latvian/mods/kubejs/recipe/RecipesEventJS (java.lang.ClassNotFoundException: dev.latvian.mods.kubejs.recipe.RecipesEventJS)
# [18:41:50] [main/WARN] [mixin/]: @Mixin target dev.latvian.mods.kubejs.recipe.RecipesEventJS was not found mixins.hammerlib.json:bs.kubejs.RecipeEventJSMixin
# [Serene Seasons Transformer]: Transforming m_47480_ (Lnet/minecraft/world/level/LevelReader;Lnet/minecraft/core/BlockPos;Z)Z in net/minecraft/world/level/biome/Biome
# [Serene Seasons Transformer]: Patched 1 calls
# [Serene Seasons Transformer]: Transforming m_47519_ (Lnet/minecraft/world/level/LevelReader;Lnet/minecraft/core/BlockPos;)Z in net/minecraft/world/level/biome/Biome
# [Serene Seasons Transformer]: Successfully patched shouldSnow
# [18:41:51] [main/WARN] [mixin/]: Error loading class: vazkii/neat/HealthBarRenderer (java.lang.ClassNotFoundException: vazkii.neat.HealthBarRenderer)
# [18:41:51] [main/WARN] [mixin/]: @Mixin target vazkii.neat.HealthBarRenderer was not found autoleveling.mixins.json:neat/HealthBarRendererMixin
# [18:41:51] [main/WARN] [mixin/]: Error loading class: dev/latvian/mods/kubejs/recipe/RecipesEventJS (java.lang.ClassNotFoundException: dev.latvian.mods.kubejs.recipe.RecipesEventJS)
# [18:41:51] [main/WARN] [mixin/]: @Mixin target dev.latvian.mods.kubejs.recipe.RecipesEventJS was not found sliceanddice.mixins.json:RecipeEventJSMixin
# [18:41:51] [main/INFO] [co.cu.Cupboard/]: Loaded config for: recipeessentials.json
# [18:41:52] [main/INFO] [co.cu.Cupboard/]: Loaded config for: structureessentials.json
# [18:41:52] [main/WARN] [mixin/]: Error loading class: de/maxhenkel/voicechat/plugins/impl/audiochannel/EntityAudioChannelImpl (java.lang.ClassNotFoundException: de.maxhenkel.voicechat.plugins.impl.audiochannel.EntityAudioChannelImpl)
# [18:41:52] [main/WARN] [mixin/]: @Mixin target de.maxhenkel.voicechat.plugins.impl.audiochannel.EntityAudioChannelImpl was not found railways-common.mixins.json:compat.voicechat.EntityAudioChannelImplMixin
# [18:41:52] [main/WARN] [mixin/]: Error loading class: de/maxhenkel/voicechat/voice/server/Server (java.lang.ClassNotFoundException: de.maxhenkel.voicechat.voice.server.Server)
# [18:41:52] [main/WARN] [mixin/]: @Mixin target de.maxhenkel.voicechat.voice.server.Server was not found railways-common.mixins.json:compat.voicechat.ServerMixin
# [18:41:52] [main/WARN] [mixin/]: Error loading class: de/maxhenkel/voicechat/voice/server/ServerWorldUtils (java.lang.ClassNotFoundException: de.maxhenkel.voicechat.voice.server.ServerWorldUtils)
# [18:41:52] [main/WARN] [mixin/]: @Mixin target de.maxhenkel.voicechat.voice.server.ServerWorldUtils was not found railways-common.mixins.json:compat.voicechat.ServerWorldUtilsMixin
# [18:41:52] [main/ERROR] [ne.mi.fm.lo.RuntimeDistCleaner/DISTXFORM]: Attempted to load class net/minecraft/client/gui/screens/multiplayer/ServerSelectionList for invalid dist DEDICATED_SERVER
# [18:41:52] [main/WARN] [mixin/]: Error loading class: net/minecraft/client/gui/screens/multiplayer/ServerSelectionList (java.lang.RuntimeException: Attempted to load class net/minecraft/client/gui/screens/multiplayer/ServerSelectionList for invalid dist DEDICATED_SERVER)
# [18:41:52] [main/WARN] [mixin/]: @Mixin target net.minecraft.client.gui.screens.multiplayer.ServerSelectionList was not found serverbrowser.mixins.json:ServerSelectionMixin
# [18:41:52] [main/WARN] [ne.to.pa.mi.MixinConfigPlugin/]: For can't fit X into 3 error fix. Delete Krypton.
# [18:41:52] [main/WARN] [ne.to.pa.mi.MixinConfigPlugin/]: For can't fit X into 3 error fix. Delete Krypton.
# [18:41:52] [main/WARN] [mixin/]: Error loading class: net/darkhax/darkutils/features/charms/CharmEffects (java.lang.ClassNotFoundException: net.darkhax.darkutils.features.charms.CharmEffects)
# [18:41:52] [main/WARN] [mixin/]: Error loading class: com/brandon3055/csg/ModEventHandler (java.lang.ClassNotFoundException: com.brandon3055.csg.ModEventHandler)
# [18:41:52] [main/WARN] [mixin/]: Error loading class: com/teamabnormals/neapolitan/common/item/DrinkItem (java.lang.ClassNotFoundException: com.teamabnormals.neapolitan.common.item.DrinkItem)
# [18:41:52] [main/WARN] [mixin/]: @Mixin target com.teamabnormals.neapolitan.common.item.DrinkItem was not found create_central_kitchen.mixins.json:common.neapolitan.DrinkItemMixin
# [18:41:52] [main/WARN] [mixin/]: Error loading class: net/orcinus/overweightfarming/blocks/CropFullBlock (java.lang.ClassNotFoundException: net.orcinus.overweightfarming.blocks.CropFullBlock)
# [18:41:52] [main/WARN] [mixin/]: @Mixin target net.orcinus.overweightfarming.blocks.CropFullBlock was not found create_central_kitchen.mixins.json:common.overweightfarming.CropFullBlockMixin
# [18:41:52] [main/INFO] [memoryleakfix/]: [MemoryLeakFix] Will be applying 2 memory leak fixes!
# [18:41:52] [main/INFO] [memoryleakfix/]: [MemoryLeakFix] Currently enabled memory leak fixes: [entityMemoriesLeak, biomeTemperatureLeak]
# [18:41:53] [main/WARN] [mixin/]: Error loading class: net/minecraft/client/renderer/blockentity/BlockEntityRendererProvider$Context (java.lang.ClassNotFoundException: net.minecraft.client.renderer.blockentity.BlockEntityRendererProvider$Context)
# [18:41:53] [main/WARN] [mixin/]: Error loading class: net/minecraft/client/renderer/blockentity/BlockEntityRendererProvider$Context (java.lang.ClassNotFoundException: net.minecraft.client.renderer.blockentity.BlockEntityRendererProvider$Context)
# [18:41:53] [main/INFO] [MixinExtras|Service/]: Initializing MixinExtras via com.llamalad7.mixinextras.service.MixinExtrasServiceImpl(version=0.3.2).
# [18:41:53] [main/WARN] [MixinExtras|Service/]: Found problematic active MixinExtras instance at ca.fxco.memoryleakfix.mixinextras (version 0.2.0-beta.8)
# [18:41:53] [main/WARN] [MixinExtras|Service/]: Versions from 0.2.0-beta.1 to 0.2.0-beta.9 have limited support and it is strongly recommended to update.
# [18:41:53] [main/INFO] [minecraft/Bootstrap]: ModernFix reached bootstrap stage (18.47 s after launch)
# [18:41:54] [main/INFO] [ne.mi.co.Co.placebo/COREMODLOG]: Patching IForgeItemStack#getEnchantmentLevel
# [18:41:54] [main/INFO] [ne.mi.co.Co.placebo/COREMODLOG]: Patching IForgeItemStack#getEnchantmentLevel
# [18:41:54] [main/WARN] [mixin/]: @Inject(@At("INVOKE")) Shift.BY=2 on everycomp-common.mixins.json:LootTableHackMixin::handler$cgb000$addSimpleFastECdrops exceeds the maximum allowed value: 0. Increase the value of maxShiftBy to suppress this warning.
# [18:41:54] [main/INFO] [ModernFix/]: Injecting BlockStateBase cache population hook into getOpacityIfCached from ca.spottedleaf.starlight.mixin.common.blockstate.BlockStateBaseMixin
# [18:41:54] [main/INFO] [ModernFix/]: Injecting BlockStateBase cache population hook into isConditionallyFullOpaque from ca.spottedleaf.starlight.mixin.common.blockstate.BlockStateBaseMixin
# [18:41:54] [main/INFO] [mixin/]: Mixing MixinLivingEntity from enigmaticlegacy.mixins.json into net.minecraft.world.entity.LivingEntity
# [Serene Seasons Transformer]: Transforming m_8714_ (Lnet/minecraft/world/level/chunk/LevelChunk;I)V in net/minecraft/server/level/ServerLevel
# [Serene Seasons Transformer]: Successfully patched tickChunk
# [18:41:54] [main/INFO] [mixin/]: Mixing MixinPlayer from enigmaticlegacy.mixins.json into net.minecraft.world.entity.player.Player
# [18:41:54] [main/INFO] [mixin/]: Mixing MixinMobEffect from enigmaticlegacy.mixins.json into net.minecraft.world.effect.MobEffect
# [18:41:55] [main/WARN] [mixin/]: @Final field f_57244_:Lnet/minecraft/world/level/block/state/properties/IntegerProperty; in QualityCrops.mixins.json:SweetBerryBushMixin should be final
# [18:41:56] [main/INFO] [minecraft/Bootstrap]: Vanilla bootstrap took 2253 milliseconds
# [18:41:56] [main/WARN] [mixin/]: @ModifyConstant conflict. Skipping connectivity.mixins.json:ClientBoundCustomPayloadPacketLMixin->@ModifyConstant::modifyLimit(I)I with priority 1, already redirected by packetfixer.mixins.json:ClientboundCustomPayloadPacketMixin->@ModifyConstant::newSize(I)I with priority 9999
# [18:41:56] [main/WARN] [mixin/]: @ModifyConstant conflict. Skipping connectivity.mixins.json:ClientBoundCustomPayloadPacketLMixin->@ModifyConstant::modifyLimit(I)I with priority 1, already redirected by packetfixer.mixins.json:ClientboundCustomPayloadPacketMixin->@ModifyConstant::newSize(I)I with priority 9999
# [Serene Seasons Transformer]: Transforming m_8107_ ()V in net/minecraft/world/entity/animal/SnowGolem
# [Serene Seasons Transformer]: Patched 1 calls
# [18:41:56] [main/INFO] [mixin/]: Mixing MixinEnchantmentContainer from enigmaticlegacy.mixins.json into net.minecraft.world.inventory.EnchantmentMenu
# [18:41:56] [main/INFO] [mixin/]: Renaming synthetic method lambda$onEnchantedItem$0(Lnet/minecraft/world/item/ItemStack;Lnet/minecraft/world/inventory/EnchantmentMenu;ILnet/minecraft/world/entity/player/Player;ILnet/minecraft/world/level/Level;Lnet/minecraft/core/BlockPos;)V to md218bb6$lambda$onEnchantedItem$0$0 in enigmaticlegacy.mixins.json:MixinEnchantmentContainer
# [ImprovableSkills]: Patching ItemStack.hurtAndBreak
# [18:41:56] [main/INFO] [mixin/]: Mixing MixinItemStack from enigmaticlegacy.mixins.json into net.minecraft.world.item.ItemStack
# [18:41:56] [main/INFO] [ne.mi.co.Co.placebo/COREMODLOG]: Patching IForgeItemStack#getEnchantmentLevel
# [18:41:56] [main/INFO] [ne.mi.co.Co.placebo/COREMODLOG]: Patching IForgeItemStack#getEnchantmentLevel
# [18:41:56] [main/WARN] [mixin/]: @Final field f_58646_:[[Lnet/minecraft/world/effect/MobEffect; in cold_sweat.mixin.json:MixinBeaconEffects should be final
# [18:41:56] [main/WARN] [mixin/]: @Final field f_58647_:Ljava/util/Set; in cold_sweat.mixin.json:MixinBeaconEffects should be final
# [18:41:57] [main/INFO] [mixin/]: Mixing AccessorAbstractArrowEntity from enigmaticlegacy.mixins.json into net.minecraft.world.entity.projectile.AbstractArrow
# [18:41:57] [main/INFO] [mixin/]: Mixing MixinEnderDragon from enigmaticlegacy.mixins.json into net.minecraft.world.entity.boss.enderdragon.EnderDragon
# [18:41:57] [main/INFO] [mixin/]: Renaming synthetic method lambda$onTickDeath$0(Lnet/minecraft/server/level/ServerPlayer;)V to md218bb6$lambda$onTickDeath$0$0 in enigmaticlegacy.mixins.json:MixinEnderDragon
# [18:41:57] [main/INFO] [mixin/]: Mixing MixinShulker from enigmaticlegacy.mixins.json into net.minecraft.world.entity.monster.Shulker
# [18:41:57] [main/INFO] [mixin/]: Mixing MixinVillagerEntity from enigmaticlegacy.mixins.json into net.minecraft.world.entity.npc.Villager
# [18:41:57] [main/INFO] [mixin/]: Mixing MixinVillager from enigmaticlegacy.mixins.json into net.minecraft.world.entity.npc.Villager
# [18:41:58] [main/WARN] [mixin/]: @ModifyConstant conflict. Skipping integrated_api.mixins.json:structures.StructurePoolMixin->@ModifyConstant::integrated_api_increaseWeightLimitDev(I)I with priority 1000, already redirected by yungsapi_forge.mixins.json:IncreaseStructureWeightLimitMixinForge->@ModifyConstant::yungsapi_increaseWeightLimit(I)I with priority 1000
# [Serene Seasons Transformer]: Transforming m_47480_ (Lnet/minecraft/world/level/LevelReader;Lnet/minecraft/core/BlockPos;Z)Z in net/minecraft/world/level/biome/Biome
# [Serene Seasons Transformer]: Patched 1 calls
# [Serene Seasons Transformer]: Transforming m_47519_ (Lnet/minecraft/world/level/LevelReader;Lnet/minecraft/core/BlockPos;)Z in net/minecraft/world/level/biome/Biome
# [Serene Seasons Transformer]: Successfully patched shouldSnow
# [18:41:58] [main/WARN] [mixin/]: Static binding violation: PRIVATE @Overwrite method m_47505_ in modernfix-common.mixins.json:perf.remove_biome_temperature_cache.BiomeMixin cannot reduce visibiliy of PUBLIC target method, visibility will be upgraded.
# [18:41:59] [main/WARN] [mixin/]: Mixin villagersplus.mixins.json:EntityBucketItemMixin has multiple constructors, (Lnet/minecraft/world/level/material/Fluid;Lnet/minecraft/world/item/Item$Properties;)V was selected
#
# [18:41:59] [main/INFO] [mixin/]: Mixing MixinEnderEyeItem from enigmaticlegacy.mixins.json into net.minecraft.world.item.EnderEyeItem
# [18:41:59] [main/INFO] [mixin/]: Mixing MixinCrossbowItem from enigmaticlegacy.mixins.json into net.minecraft.world.item.CrossbowItem
# [18:41:59] [main/ERROR] [minecraft/Util]: Registry 'integrated_api:json_conditions' was empty after loading
# [18:42:00] [modloading-worker-0/INFO] [Puzzles Lib/]: Constructing common components for mod easyanvils
# [18:42:00] [modloading-worker-0/WARN] [mixin/]: @Redirect conflict. Skipping modernfix-forge.mixins.json:perf.datapack_reload_exceptions.LootTableManagerMixin->@Redirect::logWithoutStacktrace(Lorg/slf4j/Logger;Ljava/lang/String;Ljava/lang/Object;Ljava/lang/Object;)V with priority 1000, already redirected by railways-common.mixins.json:MixinLootTables->@Redirect::snr$error2(Lorg/slf4j/Logger;Ljava/lang/String;Ljava/lang/Object;Ljava/lang/Object;)V with priority 10000
# [18:42:00] [modloading-worker-0/INFO] [mixin/]: Mixing MixinPlayerList from enigmaticlegacy.mixins.json into net.minecraft.server.players.PlayerList
# [18:42:00] [modloading-worker-0/INFO] [create_new_age/]: Hello 1.20.1 Create!
# [18:42:00] [modloading-worker-0/INFO] [Puzzles Lib/]: Constructing common components for mod leavesbegone
# [18:42:01] [modloading-worker-0/INFO] [io.wi.lm.LMFTCommon/]: [LMFT]: Loaded Config File!
# [18:42:01] [modloading-worker-0/INFO] [de.wu.bc.BCC/]: Better Compatibility Checker loading
# [18:42:01] [modloading-worker-0/INFO] [HammerLib/]: Registered charge handler for type org.zeith.hammerlib.util.charging.fluid.FluidCharge - org.zeith.hammerlib.util.charging.impl.FluidChargeHandler@71562a98
# [18:42:01] [modloading-worker-0/INFO] [HammerLib/]: Registered charge handler for type org.zeith.hammerlib.util.charging.fe.FECharge - org.zeith.hammerlib.util.charging.impl.FEChargeHandler@1599d266
# [18:42:01] [modloading-worker-0/INFO] [HammerLib/]: Registered inventory lister org.zeith.hammerlib.util.charging.impl.VanillaPlayerInvLister
# [18:42:01] [modloading-worker-0/INFO] [HammerLib/]: Hooked Lorg/zeith/hammerlib/core/test/machine/TileTestMachine; from hammerlib to register it's stuff.
# [18:42:01] [modloading-worker-0/INFO] [mixin/]: Mixing MixinEnterBlockTrigger from enigmaticlegacy.mixins.json into net.minecraft.advancements.critereon.EnterBlockTrigger
# [18:42:01] [modloading-worker-0/INFO] [HammerLib/]: Hooked Lorg/zeith/hammerlib/core/test/machine/RecipeTestMachine; from hammerlib to register it's stuff.
# [18:42:01] [modloading-worker-0/INFO] [HammerLib/]: Hooked Lorg/zeith/hammerlib/core/test/machine/BlockTestMachine; from hammerlib to register it's stuff.
# [18:42:01] [modloading-worker-0/INFO] [HammerLib/]: Hooked Lorg/zeith/hammerlib/core/items/ItemWrench; from hammerlib to register it's stuff.
# [18:42:01] [modloading-worker-0/INFO] [HammerLib/]: Hooked Lorg/zeith/hammerlib/core/init/SourceTypesHL; from hammerlib to register it's stuff.
# [18:42:01] [modloading-worker-0/INFO] [HammerLib/]: Hooked Lorg/zeith/hammerlib/api/forge/ContainerAPI; from hammerlib to register it's stuff.
# [18:42:01] [modloading-worker-0/INFO] [HammerLib/]: Hooked Lorg/zeith/improvableskills/init/SkillsIS; from improvableskills to register it's stuff.
# [18:42:01] [modloading-worker-0/INFO] [HammerLib/]: Hooked Lorg/zeith/improvableskills/init/RecipeTypesIS; from improvableskills to register it's stuff.
# [18:42:01] [modloading-worker-0/INFO] [HammerLib/]: Hooked Lorg/zeith/improvableskills/init/ParticleTypesIS; from improvableskills to register it's stuff.
# [18:42:01] [modloading-worker-0/INFO] [HammerLib/]: Hooked Lorg/zeith/improvableskills/init/PageletsIS; from improvableskills to register it's stuff.
# [18:42:01] [modloading-worker-0/INFO] [HammerLib/]: Hooked Lorg/zeith/improvableskills/init/ItemsIS; from improvableskills to register it's stuff.
# [18:42:01] [modloading-worker-0/INFO] [HammerLib/]: Hooked Lorg/zeith/improvableskills/init/GuiHooksIS; from improvableskills to register it's stuff.
# [18:42:01] [modloading-worker-0/INFO] [HammerLib/]: Hooked Lorg/zeith/improvableskills/init/AbilitiesIS; from improvableskills to register it's stuff.
# [18:42:01] [modloading-worker-0/INFO] [mixin/]: Mixing MixinInventoryChangeTrigger from enigmaticlegacy.mixins.json into net.minecraft.advancements.critereon.InventoryChangeTrigger
# [18:42:01] [modloading-worker-0/INFO] [HammerLib/]: Injecting config setup into class org.zeith.improvableskills.cfg.ConfigsIS
# [18:42:01] [modloading-worker-0/INFO] [mixin/]: Mixing MixinSummonedEntityTrigger from enigmaticlegacy.mixins.json into net.minecraft.advancements.critereon.SummonedEntityTrigger
# [18:42:01] [modloading-worker-0/INFO] [HammerLib/]: Injecting setup into org.zeith.hammerlib.net.Network.
# [18:42:01] [modloading-worker-0/INFO] [workers/]: Registering POI for ResourceKey[minecraft:block / workers:miner_block]
# [18:42:01] [modloading-worker-0/INFO] [workers/]: Registering POI for ResourceKey[minecraft:block / workers:lumberjack_block]
# [18:42:01] [modloading-worker-0/INFO] [workers/]: Registering POI for ResourceKey[minecraft:block / workers:farmer_block]
# [18:42:01] [modloading-worker-0/INFO] [workers/]: Registering POI for ResourceKey[minecraft:block / workers:merchant_block]
# [18:42:01] [modloading-worker-0/INFO] [workers/]: Registering POI for ResourceKey[minecraft:block / workers:shepherd_block]
# [18:42:01] [modloading-worker-0/INFO] [workers/]: Registering POI for ResourceKey[minecraft:block / workers:fisherman_block]
# [18:42:01] [modloading-worker-0/INFO] [workers/]: Registering POI for ResourceKey[minecraft:block / workers:cattle_farmer_block]
# [18:42:01] [modloading-worker-0/INFO] [workers/]: Registering POI for ResourceKey[minecraft:block / workers:chicken_farmer_block]
# [18:42:01] [modloading-worker-0/INFO] [workers/]: Registering POI for ResourceKey[minecraft:block / workers:swineherd_block]
# [18:42:01] [modloading-worker-0/INFO] [workers/]: Registering profession for miner with POI net.minecraftforge.registries.RegistryObject@84ce06a
# [18:42:01] [modloading-worker-0/INFO] [workers/]: Registering profession for lumberjack with POI net.minecraftforge.registries.RegistryObject@2324e55
# [18:42:01] [modloading-worker-0/INFO] [workers/]: Registering profession for farmer with POI net.minecraftforge.registries.RegistryObject@b5b6294e
# [18:42:01] [modloading-worker-0/INFO] [workers/]: Registering profession for merchant with POI net.minecraftforge.registries.RegistryObject@e3fd43b3
# [18:42:01] [modloading-worker-0/INFO] [workers/]: Registering profession for shepherd with POI net.minecraftforge.registries.RegistryObject@dc7f439a
# [18:42:01] [modloading-worker-0/INFO] [workers/]: Registering profession for fisherman with POI net.minecraftforge.registries.RegistryObject@2b647820
# [18:42:01] [modloading-worker-0/INFO] [workers/]: Registering profession for cattle_farmer with POI net.minecraftforge.registries.RegistryObject@2fbf1d36
# [18:42:01] [modloading-worker-0/INFO] [workers/]: Registering profession for chicken_farmer with POI net.minecraftforge.registries.RegistryObject@8de71318
# [18:42:01] [modloading-worker-0/INFO] [workers/]: Registering profession for swineherd with POI net.minecraftforge.registries.RegistryObject@5a68aad6
# [18:42:02] [modloading-worker-0/INFO] [co.ae.cu.Cumulus/]: Disabling Cumulus as it is on server.
# [18:42:02] [modloading-worker-0/INFO] [Puzzles Lib/]: Constructing common components for mod visualworkbench
# [18:42:02] [modloading-worker-0/INFO] [Puzzles Lib/]: Constructing common components for mod mindfuldarkness
# [18:42:02] [modloading-worker-0/INFO] [Kiwi/Init]: Processing 3 KiwiModule annotations
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: loading json file and contents for paintings.
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: **Paintings++ no longer copies the base file outside if the mod. **
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting abstract_blue , 16 x 16
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting abstract_rainbow , 16 x 16
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting abstract_red , 16 x 16
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting abstract_sunset , 16 x 16
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting arachnophobe , 32 x 16
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting barn_owl , 32 x 16
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting big_z , 16 x 16
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting blue_bird , 32 x 16
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting bluesclues , 32 x 16
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting borgia , 16 x 32
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting cane , 16 x 32
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting cat_black , 16 x 16
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting cat_gray , 16 x 16
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting cat_orange , 16 x 16
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting cat , 32 x 16
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting colorful_squares , 32 x 16
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting crest , 32 x 16
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting danger_zone , 32 x 32
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting decorative_gun , 32 x 16
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting exit_down , 32 x 16
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting exit_up , 32 x 16
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting exit_left , 32 x 16
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting exit_right , 32 x 16
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting face_bat , 16 x 16
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting face_chicken , 16 x 16
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting face_cow , 16 x 16
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting face_creeper , 16 x 16
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting face_dog , 16 x 16
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting face_enderman , 16 x 16
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting face_pig , 16 x 16
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting face_pigman , 16 x 16
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting face_silverfish , 16 x 16
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting face_skeleton , 16 x 16
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting face_squid , 16 x 16
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting face_zombie , 16 x 16
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting fishes , 32 x 16
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting flowers , 32 x 16
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting fruits , 32 x 16
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting ghost , 16 x 32
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting glowlamp , 32 x 32
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting glowstone_hourglass , 16 x 32
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting iluvmc , 32 x 16
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting link , 32 x 16
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting mine_prosperity , 32 x 16
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting no_trespassing_for_mobs , 32 x 16
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting ocelot , 16 x 16
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting penguin , 32 x 16
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting pig_on_a_cliff , 32 x 32
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting pkmn_blue , 32 x 16
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting pkmn_red , 32 x 16
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting pkmn_green , 32 x 16
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting plains_hut , 32 x 16
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting portrait_2 , 16 x 16
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting portrait , 32 x 32
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting prison , 16 x 32
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting prosperity , 16 x 32
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting rest , 32 x 16
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting skeleton , 16 x 32
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting sky , 32 x 32
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting skyblock , 32 x 32
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting snake , 16 x 32
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting snow_landscape , 32 x 16
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting subaraki , 32 x 16
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting synth_city , 16 x 16
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting tapistry_a , 32 x 16
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting tapistry_b , 16 x 32
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting tapistry_purple , 16 x 32
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting torched , 32 x 16
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting waterfall , 32 x 16
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting whale , 32 x 16
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting wheat_field , 32 x 16
# [18:42:02] [modloading-worker-0/INFO] [paintings/]: Loaded json painting wolf_in_wheat , 32 x 16
# [18:42:02] [modloading-worker-0/INFO] [ne.mi.co.ForgeMod/FORGEMOD]: Forge mod loading, version 43.3.8, for MC 1.19.2 with MCP 20220805.130853
# [18:42:02] [modloading-worker-0/INFO] [ne.mi.co.MinecraftForge/FORGE]: MinecraftForge v43.3.8 Initialized
# [18:42:03] [modloading-worker-0/INFO] [Puzzles Lib/]: Constructing common components for mod puzzleslib
# [18:42:03] [modloading-worker-0/INFO] [th.ko.te.KotlinForForge/]: Kotlin For Forge Enabled!
# [18:42:03] [Modding Legacy/blue_skies/Supporters thread/INFO] [ModdingLegacy/blue_skies/Supporter/]: Attempting to load the Modding Legacy supporters list from https://moddinglegacy.com/supporters-changelogs/supporters.txt
# [18:42:03] [Modding Legacy/blue_skies/Supporters thread/INFO] [ModdingLegacy/blue_skies/Supporter/]: Successfully loaded the Modding Legacy supporters list.
# [18:42:04] [modloading-worker-0/INFO] [Collective/]: [Collective] JSON file 'entity_names.json' generation requested by mod 'villagernames'.
# [18:42:04] [modloading-worker-0/INFO] [Bookshelf/]: Fixing MC-151457. Crafting remainder for minecraft:pufferfish_bucket is now minecraft:bucket.
# [18:42:04] [modloading-worker-0/INFO] [Bookshelf/]: Fixing MC-151457. Crafting remainder for minecraft:salmon_bucket is now minecraft:bucket.
# [18:42:04] [modloading-worker-0/INFO] [Bookshelf/]: Fixing MC-151457. Crafting remainder for minecraft:cod_bucket is now minecraft:bucket.
# [18:42:04] [modloading-worker-0/INFO] [Bookshelf/]: Fixing MC-151457. Crafting remainder for minecraft:tropical_fish_bucket is now minecraft:bucket.
# [18:42:04] [modloading-worker-0/INFO] [Bookshelf/]: Fixing MC-151457. Crafting remainder for minecraft:axolotl_bucket is now minecraft:bucket.
# [18:42:04] [modloading-worker-0/INFO] [Bookshelf/]: Fixing MC-151457. Crafting remainder for minecraft:powder_snow_bucket is now minecraft:bucket.
# [18:42:04] [modloading-worker-0/INFO] [Bookshelf/]: Fixing MC-151457. Crafting remainder for minecraft:tadpole_bucket is now minecraft:bucket.
# [18:42:04] [modloading-worker-0/INFO] [pl.dr.cr.DragonLib/]: Create: Dragon Lib 1.2.3 has initialized, ready to support your Create add-ons!
# [18:42:04] [modloading-worker-0/INFO] [Create: Interiors/]: Create: Interiors v0.5.2 initializing
# [18:42:04] [modloading-worker-0/INFO] [de.ke.ko.Konkrete/]: [KONKRETE] Successfully initialized!
# [18:42:04] [modloading-worker-0/INFO] [de.ke.ko.Konkrete/]: [KONKRETE] Server-side libs ready to use!
# [18:42:04] [modloading-worker-0/INFO] [Create: Interiors/]: Registering blocks!
# [18:42:04] [modloading-worker-0/WARN] [mixin/]: @Final field VINE_AGE:Lnet/minecraft/world/level/block/state/properties/IntegerProperty; in qualitysdelight.mixins.json:TomatoVineMixin should be final
# [18:42:05] [modloading-worker-0/INFO] [railways/]: Registered bogey styles from railways
# [18:42:05] [modloading-worker-0/INFO] [co.cu.Cupboard/]: Loaded config for: memorysettings.json
# [18:42:05] [modloading-worker-0/WARN] [co.me.MemorysettingsMod/]: You have less memory allocated(3996mb) than recommended for this pack, the minimum is: 4000mb.
# The recommended amount for your system is: 7995 mb.
#
# [18:42:05] [modloading-worker-0/INFO] [Collective/]: Loading Collective version 7.30.
# [18:42:05] [modloading-worker-0/INFO] [Enigmatic Legacy/INFO]: Constructing mod instance...
# [18:42:05] [modloading-worker-0/INFO] [railways/]: Registering data fixers
# [18:42:05] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id architectury:sync_ids
# [18:42:05] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftblibrary:edit_nbt_response
# [18:42:05] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbteams:open_gui
# [18:42:05] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbteams:update_settings
# [18:42:05] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbteams:send_message
# [18:42:05] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbteams:create_party
# [18:42:05] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbteams:player_gui_operation
# [18:42:05] [modloading-worker-0/INFO] [ModernFix/]: Bypassed Mojang DFU
# [18:42:05] [modloading-worker-0/INFO] [ModernFix/]: Instantiating Mojang DFU
# [18:42:05] [modloading-worker-0/INFO] [Puzzles Lib/]: Constructing common components for mod tradingpost
# [18:42:05] [modloading-worker-0/INFO] [Enigmatic Legacy/INFO]: Mod instance constructed successfully.
# [18:42:05] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id itemfilters:main/14e7fa1454283aec8ae811ef844ada28
# [18:42:05] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id itemfilters:main/8f6a899247753217b9d86ab427a2b279
# [18:42:05] [modloading-worker-0/INFO] [FTB XMod Compat/]: Chose [Entity Tags] as the active game stages implementation
# [18:42:05] [modloading-worker-0/INFO] [FTB XMod Compat/]: Chose [FALLBACK] as the active permissions implementation
# [18:42:05] [modloading-worker-0/INFO] [FTB XMod Compat/]: [FTB Quests] recipe helper provider is [JEI]
# [18:42:05] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:submit_task
# [18:42:05] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:claim_reward
# [18:42:05] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:get_emergency_items
# [18:42:05] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:claim_all_rewards
# [18:42:05] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:claim_choice_reward
# [18:42:05] [modloading-worker-0/INFO] [Puzzles Lib/]: Constructing common components for mod easymagic
# [18:42:05] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:toggle_pinned
# [18:42:05] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:toggle_chapter_pinned
# [18:42:06] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:toggle_editing_mode
# [18:42:06] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:force_save
# [18:42:06] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:set_custom_image
# [18:42:06] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:task_screen_config_resp
# [18:42:06] [modloading-worker-0/ERROR] [ne.mi.ev.EventSubclassTransformer/EVENTBUS]: Could not find parent net/minecraft/client/renderer/entity/layers/RenderLayer for class com/obscuria/obscureapi/client/renderer/PatreonLayer in classloader cpw.mods.modlauncher.TransformingClassLoader@40a7974 on thread Thread[#37,modloading-worker-0,5,main]
# [18:42:06] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:change_progress
# [18:42:06] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:create_object
# [18:42:06] [modloading-worker-0/ERROR] [ne.mi.ev.EventSubclassTransformer/EVENTBUS]: An error occurred building event handler
# java.lang.ClassNotFoundException: net.minecraft.client.renderer.entity.layers.RenderLayer
# 	at cpw.mods.cl.ModuleClassLoader.loadClass(ModuleClassLoader.java:141) ~[securejarhandler-2.1.4.jar:?] {}
# 	at java.lang.ClassLoader.loadClass(ClassLoader.java:526) ~[?:?] {}
# 	at net.minecraftforge.eventbus.EventSubclassTransformer.buildEvents(EventSubclassTransformer.java:92) ~[eventbus-6.0.3.jar%2351!/:?] {}
# 	at net.minecraftforge.eventbus.EventSubclassTransformer.transform(EventSubclassTransformer.java:44) ~[eventbus-6.0.3.jar%2351!/:?] {}
# 	at net.minecraftforge.eventbus.EventBusEngine.processClass(EventBusEngine.java:26) ~[eventbus-6.0.3.jar%2351!/:?] {}
# 	at net.minecraftforge.eventbus.service.ModLauncherService.processClassWithFlags(ModLauncherService.java:32) ~[eventbus-6.0.3.jar%2351!/:6.0.3+6.0.3+master.039e4ea9] {}
# 	at cpw.mods.modlauncher.LaunchPluginHandler.offerClassNodeToPlugins(LaunchPluginHandler.java:88) ~[modlauncher-10.0.8.jar%2354!/:?] {}
# 	at cpw.mods.modlauncher.ClassTransformer.transform(ClassTransformer.java:120) ~[modlauncher-10.0.8.jar%2354!/:?] {}
# 	at cpw.mods.modlauncher.TransformingClassLoader.maybeTransformClassBytes(TransformingClassLoader.java:50) ~[modlauncher-10.0.8.jar%2354!/:?] {}
# 	at cpw.mods.cl.ModuleClassLoader.readerToClass(ModuleClassLoader.java:113) ~[securejarhandler-2.1.4.jar:?] {}
# 	at cpw.mods.cl.ModuleClassLoader.lambda$findClass$15(ModuleClassLoader.java:219) ~[securejarhandler-2.1.4.jar:?] {}
# 	at cpw.mods.cl.ModuleClassLoader.loadFromModule(ModuleClassLoader.java:229) ~[securejarhandler-2.1.4.jar:?] {}
# 	at cpw.mods.cl.ModuleClassLoader.findClass(ModuleClassLoader.java:219) ~[securejarhandler-2.1.4.jar:?] {}
# 	at cpw.mods.cl.ModuleClassLoader.loadClass(ModuleClassLoader.java:135) ~[securejarhandler-2.1.4.jar:?] {}
# 	at java.lang.ClassLoader.loadClass(ClassLoader.java:526) ~[?:?] {}
# 	at java.lang.ClassLoader.defineClass0(Native Method) ~[?:?] {}
# 	at java.lang.System$2.defineClass(System.java:2394) ~[?:?] {}
# 	at java.lang.invoke.MethodHandles$Lookup$ClassDefiner.defineClass(MethodHandles.java:2505) ~[?:?] {}
# 	at java.lang.invoke.InnerClassLambdaMetafactory.generateInnerClass(InnerClassLambdaMetafactory.java:361) ~[?:?] {}
# 	at java.lang.invoke.InnerClassLambdaMetafactory.spinInnerClass(InnerClassLambdaMetafactory.java:286) ~[?:?] {}
# 	at java.lang.invoke.InnerClassLambdaMetafactory.buildCallSite(InnerClassLambdaMetafactory.java:221) ~[?:?] {}
# 	at java.lang.invoke.LambdaMetafactory.metafactory(LambdaMetafactory.java:341) ~[?:?] {}
# 	at java.lang.invoke.BootstrapMethodInvoker.invoke(BootstrapMethodInvoker.java:134) ~[?:?] {}
# 	at java.lang.invoke.CallSite.makeSite(CallSite.java:316) ~[?:?] {re:mixin}
# 	at java.lang.invoke.MethodHandleNatives.linkCallSiteImpl(MethodHandleNatives.java:274) ~[?:?] {}
# 	at java.lang.invoke.MethodHandleNatives.linkCallSite(MethodHandleNatives.java:264) ~[?:?] {}
# 	at com.obscuria.obscureapi.client.renderer.PatreonLayer$Mode.<clinit>(PatreonLayer.java:55) ~[obscure_api-15.jar%23514!/:15] {re:classloading}
# 	at com.obscuria.obscureapi.ObscureAPIConfig$Client.<clinit>(ObscureAPIConfig.java:26) ~[obscure_api-15.jar%23514!/:15] {re:classloading}
# 	at com.obscuria.obscureapi.ObscureAPIConfig.register(ObscureAPIConfig.java:42) ~[obscure_api-15.jar%23514!/:15] {re:classloading}
# 	at com.obscuria.obscureapi.ObscureAPI.<init>(ObscureAPI.java:68) ~[obscure_api-15.jar%23514!/:15] {re:classloading}
# 	at jdk.internal.reflect.DirectConstructorHandleAccessor.newInstance(DirectConstructorHandleAccessor.java:62) ~[?:?] {}
# 	at java.lang.reflect.Constructor.newInstanceWithCaller(Constructor.java:502) ~[?:?] {}
# 	at java.lang.reflect.Constructor.newInstance(Constructor.java:486) ~[?:?] {}
# 	at net.minecraftforge.fml.javafmlmod.FMLModContainer.constructMod(FMLModContainer.java:70) ~[javafmllanguage-1.19.2-43.3.8.jar%23611!/:?] {}
# 	at net.minecraftforge.fml.ModContainer.lambda$buildTransitionHandler$4(ModContainer.java:122) ~[fmlcore-1.19.2-43.3.8.jar%23610!/:?] {re:mixin}
# 	at java.util.concurrent.CompletableFuture$AsyncRun.run(CompletableFuture.java:1804) [?:?] {}
# 	at java.util.concurrent.CompletableFuture$AsyncRun.exec(CompletableFuture.java:1796) [?:?] {}
# 	at java.util.concurrent.ForkJoinTask.doExec(ForkJoinTask.java:387) [?:?] {}
# 	at java.util.concurrent.ForkJoinPool$WorkQueue.topLevelExec(ForkJoinPool.java:1312) [?:?] {}
# 	at java.util.concurrent.ForkJoinPool.scan(ForkJoinPool.java:1843) [?:?] {re:mixin,re:computing_frames}
# 	at java.util.concurrent.ForkJoinPool.runWorker(ForkJoinPool.java:1808) [?:?] {re:mixin,re:computing_frames}
# 	at java.util.concurrent.ForkJoinWorkerThread.run(ForkJoinWorkerThread.java:188) [?:?] {re:mixin}
# [18:42:06] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:create_task_at
# [18:42:06] [modloading-worker-0/ERROR] [ne.mi.fm.lo.RuntimeDistCleaner/DISTXFORM]: Attempted to load class com/obscuria/obscureapi/client/renderer/PatreonLayer for invalid dist DEDICATED_SERVER
# [18:42:06] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:delete_object
# [18:42:06] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:edit_object
# [18:42:06] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:move_chapter
# [18:42:06] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:move_quest
# [18:42:06] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:change_chapter_group
# [18:42:06] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:move_chapter_group
# [18:42:06] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:copy_quest
# ...
# [18:42:42] [Server thread/WARN] [co.gi.al.al.AlexsMobs/]: could not test biome config for alexsmobs:fly_spawns, defaulting to no spawns for mob
# [18:42:42] [Server thread/WARN] [co.gi.al.al.AlexsMobs/]: could not test biome config for alexsmobs:fly_spawns, defaulting to no spawns for mob
# [18:42:42] [Server thread/WARN] [co.gi.al.al.AlexsMobs/]: could not test biome config for alexsmobs:fly_spawns, defaulting to no spawns for mob
# [18:42:42] [Server thread/WARN] [co.gi.al.al.AlexsMobs/]: could not test biome config for alexsmobs:fly_spawns, defaulting to no spawns for mob
# [18:42:42] [Server thread/WARN] [co.gi.al.al.AlexsMobs/]: could not test biome config for alexsmobs:fly_spawns, defaulting to no spawns for mob
# [18:42:42] [Server thread/WARN] [co.gi.al.al.AlexsMobs/]: could not test biome config for alexsmobs:fly_spawns, defaulting to no spawns for mob
# [18:42:42] [Server thread/WARN] [co.gi.al.al.AlexsMobs/]: could not test biome config for alexsmobs:fly_spawns, defaulting to no spawns for mob
# [18:42:42] [Server thread/WARN] [co.gi.al.al.AlexsMobs/]: could not test biome config for alexsmobs:fly_spawns, defaulting to no spawns for mob
# [18:42:42] [Server thread/WARN] [co.gi.al.al.AlexsMobs/]: could not test biome config for alexsmobs:fly_spawns, defaulting to no spawns for mob
# [18:42:42] [Server thread/WARN] [co.gi.al.al.AlexsMobs/]: could not test biome config for alexsmobs:fly_spawns, defaulting to no spawns for mob
# [18:42:42] [Server thread/WARN] [co.gi.al.al.AlexsMobs/]: could not test biome config for alexsmobs:fly_spawns, defaulting to no spawns for mob
# [18:42:42] [Server thread/WARN] [co.gi.al.al.AlexsMobs/]: could not test biome config for alexsmobs:fly_spawns, defaulting to no spawns for mob
# [18:42:42] [Server thread/WARN] [co.gi.al.al.AlexsMobs/]: could not test biome config for alexsmobs:fly_spawns, defaulting to no spawns for mob
# [18:42:42] [Server thread/WARN] [co.gi.al.al.AlexsMobs/]: could not test biome config for alexsmobs:fly_spawns, defaulting to no spawns for mob
# [18:42:42] [Server thread/WARN] [co.gi.al.al.AlexsMobs/]: could not test biome config for alexsmobs:fly_spawns, defaulting to no spawns for mob
# [18:42:42] [Server thread/WARN] [co.gi.al.al.AlexsMobs/]: could not test biome config for alexsmobs:fly_spawns, defaulting to no spawns for mob
# [18:42:42] [Server thread/WARN] [co.gi.al.al.AlexsMobs/]: could not test biome config for alexsmobs:fly_spawns, defaulting to no spawns for mob
# [18:42:42] [Server thread/WARN] [co.gi.al.al.AlexsMobs/]: could not test biome config for alexsmobs:fly_spawns, defaulting to no spawns for mob
# [18:42:42] [Server thread/WARN] [co.gi.al.al.AlexsMobs/]: could not test biome config for alexsmobs:fly_spawns, defaulting to no spawns for mob
# [18:42:42] [Server thread/WARN] [co.gi.al.al.AlexsMobs/]: could not test biome config for alexsmobs:fly_spawns, defaulting to no spawns for mob
# [18:42:42] [Server thread/WARN] [co.gi.al.al.AlexsMobs/]: could not test biome config for alexsmobs:fly_spawns, defaulting to no spawns for mob
# [18:42:42] [Server thread/WARN] [co.gi.al.al.AlexsMobs/]: could not test biome config for alexsmobs:fly_spawns, defaulting to no spawns for mob
# [18:42:42] [Server thread/WARN] [co.gi.al.al.AlexsMobs/]: could not test biome config for alexsmobs:fly_spawns, defaulting to no spawns for mob
# [18:42:42] [Server thread/WARN] [co.gi.al.al.AlexsMobs/]: could not test biome config for alexsmobs:fly_spawns, defaulting to no spawns for mob
# [18:42:42] [Server thread/WARN] [co.gi.al.al.AlexsMobs/]: could not test biome config for alexsmobs:fly_spawns, defaulting to no spawns for mob
# [18:42:42] [Server thread/WARN] [co.gi.al.al.AlexsMobs/]: could not test biome config for alexsmobs:fly_spawns, defaulting to no spawns for mob
# [18:42:42] [Server thread/WARN] [co.gi.al.al.AlexsMobs/]: could not test biome config for alexsmobs:fly_spawns, defaulting to no spawns for mob
# [18:42:42] [Server thread/WARN] [co.gi.al.al.AlexsMobs/]: could not test biome config for alexsmobs:fly_spawns, defaulting to no spawns for mob
# [18:42:42] [Server thread/WARN] [co.gi.al.al.AlexsMobs/]: could not test biome config for alexsmobs:fly_spawns, defaulting to no spawns for mob
# [18:42:42] [Server thread/WARN] [co.gi.al.al.AlexsMobs/]: could not test biome config for alexsmobs:fly_spawns, defaulting to no spawns for mob
# [18:42:42] [Server thread/WARN] [co.gi.al.al.AlexsMobs/]: could not test biome config for alexsmobs:fly_spawns, defaulting to no spawns for mob
# [18:42:42] [Server thread/WARN] [co.gi.al.al.AlexsMobs/]: could not test biome config for alexsmobs:fly_spawns, defaulting to no spawns for mob
# [18:42:42] [Server thread/WARN] [co.gi.al.al.AlexsMobs/]: could not test biome config for alexsmobs:fly_spawns, defaulting to no spawns for mob
# [18:42:42] [Server thread/INFO] [FTB Teams/]: loaded team data: 2 known players, 2 teams total
# [18:42:42] [Server thread/INFO] [xa.pa.OpenPartiesAndClaims/]: Initializing Open Parties and Claims for the server...
# [18:42:42] [Server thread/INFO] [xa.pa.OpenPartiesAndClaims/]: Loading server info!
# [18:42:42] [Server thread/INFO] [xa.pa.OpenPartiesAndClaims/]: Loading player configs...
# [18:42:42] [Server thread/INFO] [xa.pa.OpenPartiesAndClaims/]: Loaded player configs!
# [18:42:42] [Server thread/INFO] [xa.pa.OpenPartiesAndClaims/]: Loading parties...
# [18:42:42] [Server thread/INFO] [xa.pa.OpenPartiesAndClaims/]: Loaded parties!
# [18:42:42] [Server thread/INFO] [xa.pa.OpenPartiesAndClaims/]: Fixing party inconsistencies...
# [18:42:42] [Server thread/INFO] [xa.pa.OpenPartiesAndClaims/]: Registered party system for OPAC: default
# [18:42:42] [Server thread/INFO] [xa.pa.OpenPartiesAndClaims/]: Registered party system for OPAC: ftb_teams
# [18:42:42] [Server thread/INFO] [xa.pa.OpenPartiesAndClaims/]: Registered permission system for OPAC: permission_api
# [18:42:42] [Server thread/INFO] [co.in.al.AllBarkAllBite/]: Adding structure piece all_bark_all_bite:village/common/animals/dog_black to structure template pool minecraft:village/common/cats with weight 1
# [18:42:42] [Server thread/INFO] [co.in.al.AllBarkAllBite/]: Adding structure piece all_bark_all_bite:village/common/animals/dog_blue to structure template pool minecraft:village/common/cats with weight 1
# [18:42:42] [Server thread/INFO] [co.in.al.AllBarkAllBite/]: Adding structure piece all_bark_all_bite:village/common/animals/dog_brown to structure template pool minecraft:village/common/cats with weight 1
# [18:42:42] [Server thread/INFO] [co.in.al.AllBarkAllBite/]: Adding structure piece all_bark_all_bite:village/common/animals/dog_cream to structure template pool minecraft:village/common/cats with weight 1
# [18:42:42] [Server thread/INFO] [co.in.al.AllBarkAllBite/]: Adding structure piece all_bark_all_bite:village/common/animals/dog_gold to structure template pool minecraft:village/common/cats with weight 1
# [18:42:42] [Server thread/INFO] [co.in.al.AllBarkAllBite/]: Adding structure piece all_bark_all_bite:village/common/animals/dog_gray to structure template pool minecraft:village/common/cats with weight 1
# [18:42:42] [Server thread/INFO] [co.in.al.AllBarkAllBite/]: Adding structure piece all_bark_all_bite:village/common/animals/dog_red to structure template pool minecraft:village/common/cats with weight 1
# [18:42:42] [Server thread/INFO] [co.in.al.AllBarkAllBite/]: Adding structure piece all_bark_all_bite:village/common/animals/dog_white to structure template pool minecraft:village/common/cats with weight 1
# [18:42:42] [Server thread/INFO] [co.in.al.AllBarkAllBite/]: Adding structure piece all_bark_all_bite:village/common/animals/dog_yellow to structure template pool minecraft:village/common/cats with weight 1
# [18:42:42] [Server thread/INFO] [co.in.al.AllBarkAllBite/]: Adding structure piece all_bark_all_bite:pillager_outpost/feature_kennel to structure template pool minecraft:pillager_outpost/features with weight 1
# [18:42:42] [Server thread/INFO] [co.in.al.AllBarkAllBite/]: Added RaiderType for entity type entity.all_bark_all_bite.houndmaster with wave counts [0, 0, 0, 0, 0, 1, 1, 2]
# [18:42:42] [Server thread/INFO] [Framework/]: Loading server configs...
# [18:42:42] [Server thread/INFO] [terrablender/]: Initialized TerraBlender biomes for level stem minecraft:the_nether
# [18:42:42] [Server thread/INFO] [terrablender/]: Initialized TerraBlender biomes for level stem minecraft:overworld
# [18:42:43] [Server thread/INFO] [terrablender/]: Initialized TerraBlender biomes for level stem aether:the_aether
# [18:42:43] [Server thread/INFO] [minecraft/DedicatedServer]: Preparing level "world"
# [18:42:43] [Server thread/INFO] [mixin/]: Mixing MixinPhantomSpawner from enigmaticlegacy.mixins.json into net.minecraft.world.level.levelgen.PhantomSpawner
# [18:42:43] [Server thread/INFO] [minecraft/MinecraftServer]: Preparing start region for dimension minecraft:overworld
# > [18:42:44] [Server thread/WARN] [mixin/]: @Redirect conflict. Skipping redirector.mixins.json:net.minecraft.world.level.block.state.CacheMixin->@Redirect::redirectSupportTypes()[Lnet/minecraft/world/level/block/SupportType; with priority 10, already redirected by modernfix-common.mixins.json:perf.cache_blockstate_cache_arrays.AbstractBlockStateCacheMixin->@Redirect::getVoxelShapeValues()[Lnet/minecraft/world/level/block/SupportType; with priority 1000
# [18:42:45] [Server thread/INFO] [minecraft/LoggerChunkProgressListener]: Preparing spawn area: 0%
# [18:42:45] [Server thread/INFO] [minecraft/LoggerChunkProgressListener]: Preparing spawn area: 0%
# [18:42:45] [Server thread/INFO] [minecraft/LoggerChunkProgressListener]: Preparing spawn area: 0%
# [18:42:45] [Server thread/INFO] [minecraft/LoggerChunkProgressListener]: Preparing spawn area: 0%
# [18:42:45] [Server thread/INFO] [co.cu.Cupboard/]: Loaded config for: betterchunkloading.json
# [18:42:45] [Server thread/INFO] [minecraft/LoggerChunkProgressListener]: Preparing spawn area: 26%
# [18:42:46] [Server thread/INFO] [minecraft/LoggerChunkProgressListener]: Preparing spawn area: 60%
# [18:42:46] [Server thread/INFO] [minecraft/LoggerChunkProgressListener]: Time elapsed: 2882 ms
# [18:42:46] [Server thread/INFO] [minecraft/DedicatedServer]: Done (4.828s)! For help, type "help"
# [18:42:46] [Server thread/INFO] [ne.mi.se.pe.PermissionAPI/]: Successfully initialized permission handler forge:default_handler
# [18:42:46] [Server thread/INFO] [xa.pa.OpenPartiesAndClaims/]: Loading claims...
# [18:42:46] [Server thread/INFO] [xa.pa.OpenPartiesAndClaims/]: Loaded claims in 0ms
# [18:42:46] [Server thread/WARN] [xa.pa.OpenPartiesAndClaims/]: The configured permission system "ftb_ranks" isn't registered!
# [18:42:46] [Server thread/INFO] [xa.pa.OpenPartiesAndClaims/]: Configured OPAC to use the following permission system: permission_api
# [18:42:46] [Server thread/INFO] [xa.pa.OpenPartiesAndClaims/]: Configured OPAC to use the following party system as primary: ftb_teams
# [18:42:46] [Server thread/INFO] [co.mt.qu.QualityCrops/]: HELLO from server starting
# [18:42:46] [Server thread/INFO] [HammerLib/]: Reloading recipes in 0 HL recipe registries.
# [18:42:46] [Server thread/INFO] [xa.co.MinimapLogs/]: Registered synced player tracker system: ftb_teams
# [18:42:46] [Server thread/INFO] [ne.st.in.Incendium/]: Thanks for choosing Incendium!
# [18:42:46] [Server thread/INFO] [xa.ma.WorldMap/]: Registered synced player tracker system: ftb_teams
# [18:42:46] [Server thread/INFO] [co.ma.de.CreateMMBuilding/]: :3
# [18:42:46] [Server thread/INFO] [co.mt.qu.QualitysDelight/]: HELLO from server starting
# [18:42:46] [Server thread/INFO] [co.ax.en.EndersDelight/]: HELLO from server starting
# [18:42:46] [Server thread/INFO] [FTB Quests/]: Loading quests from /workspaces/codespaces-jupyter/Minecraft-server/config/ftbquests/quests
# [18:42:46] [Server thread/INFO] [FTB Quests/]: Loaded 4 chapter groups, 26 chapters, 989 quests, 5 reward tables
# [18:42:46] [Server thread/INFO] [co.cu.Cupboard/]: Loaded config for: biomemusic.json
# [18:42:46] [Server thread/INFO] [co.cu.Cupboard/]: Loaded config for: farsight.json
# [18:42:46] [Server thread/INFO] [co.cu.Cupboard/]: Loaded config for: betterfpsdist.json
# [18:42:46] [Server thread/INFO] [co.cu.Cupboard/]: Loaded config for: dragonfight.json
# [18:42:46] [Server thread/INFO] [co.cu.Cupboard/]: Loaded config for: connectivity.json
# [18:42:46] [Server thread/INFO] [co.cu.Cupboard/]: Loaded config for: lootintegrations.json
# [18:42:46] [Server thread/INFO] [co.cu.Cupboard/]: Loaded config for: cupboard.json
# [18:42:46] [Server thread/INFO] [co.cu.Cupboard/]: Loaded config for: smoothchunk.json
# [18:42:46] [Server thread/INFO] [co.cu.Cupboard/]: Loaded config for: chunksending.json
# [18:42:46] [Server thread/INFO] [patchouli/]: Sending reload packet to clients
# [18:42:47] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 jet_suit_pants, missing knowledge for {1 netherite_space_pants=1.0}
# [18:42:47] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 radiator, missing knowledge for {1 water_bucket=0.25}
# [18:42:47] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 netherite_space_helmet, missing knowledge for {1 netherite_helmet=1.0}
# [18:42:47] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 netherite_space_pants, missing knowledge for {1 netherite_leggings=1.0}
# [18:42:47] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 jet_suit_helmet, missing knowledge for {1 netherite_space_helmet=1.0}
# [18:42:47] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 jet_suit_boots, missing knowledge for {1 netherite_space_boots=1.0}
# [18:42:47] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 netherite_space_boots, missing knowledge for {1 netherite_boots=1.0}
# [18:42:47] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 forbidden_axe, missing knowledge for {1 diamond_axe=1.0}
# [18:42:47] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 netherite_space_suit, missing knowledge for {1 netherite_chestplate=1.0}
# [18:42:47] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 jet_suit, missing knowledge for {1 netherite_space_suit=1.0}
# [18:42:47] [Server thread/INFO] [immersiveengineering/]: Finished recipe profiler for Arc Recycling, took 140 milliseconds
# [18:42:47] [Server thread/WARN] [ModernFix/]: Dedicated server took 71.603 seconds to load
# >
# >[18:44:38] [Server console handler/ERROR] [minecraft/DedicatedServer]: Caught previously unhandled exception :
# java.lang.NoClassDefFoundError: org/jline/terminal/Terminal$MouseTracking
# 	at org.jline.reader.impl.LineReaderImpl.doCleanup(LineReaderImpl.java:2432) ~[jline-reader-3.12.1.jar%2361!/:?] {}
# 	at org.jline.reader.impl.LineReaderImpl.cleanup(LineReaderImpl.java:2419) ~[jline-reader-3.12.1.jar%2361!/:?] {}
# 	at org.jline.reader.impl.LineReaderImpl.readLine(LineReaderImpl.java:648) ~[jline-reader-3.12.1.jar%2361!/:?] {}
# 	at org.jline.reader.impl.LineReaderImpl.readLine(LineReaderImpl.java:418) ~[jline-reader-3.12.1.jar%2361!/:?] {}
# 	at net.minecraftforge.server.console.TerminalHandler.handleCommands(TerminalHandler.java:46) ~[forge-1.19.2-43.3.8-universal.jar%23614!/:?] {re:classloading}
# 	at net.minecraft.server.dedicated.DedicatedServer$1.run(DedicatedServer.java:85) ~[server-1.19.2-20220805.130853-srg.jar%23609!/:?] {re:classloading}
# Caused by: java.lang.ClassNotFoundException: org.jline.terminal.Terminal$MouseTracking
# 	at cpw.mods.cl.ModuleClassLoader.loadClass(ModuleClassLoader.java:141) ~[securejarhandler-2.1.4.jar:?] {}
# 	at java.lang.ClassLoader.loadClass(ClassLoader.java:526) ~[?:?] {}
# 	... 6 more
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 255
#     252 # Ciclo para realizar las solicitudes a JSONPlaceholder cada minuto
#     254 while True:
# --> 255     time.sleep(60)  # Espera 1 minuto
#
# KeyboardInterrupt:
